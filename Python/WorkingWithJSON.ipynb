# %% [markdown]
# ### Part 1.

# %%
import numpy as np
import pandas as pd
from pandas import json_normalize

# %%
# Read
data = pd.read_json('data/roam_prescription_based_prediction.jsonl', lines = True, orient='columns')
data.shape
# Out:
# (239930, 3)

# %%
data.head()
# Out:
#                              cms_prescription_counts  \
# 0  {'DOXAZOSIN MESYLATE': 26, 'MIDODRINE HCL': 12...
# 1  {'CEPHALEXIN': 23, 'AMOXICILLIN': 52, 'HYDROCO...
# 2  {'CEPHALEXIN': 28, 'AMOXICILLIN': 73, 'CLINDAM...
# 3                                {'AMOXICILLIN': 63}
# 4  {'PIOGLITAZONE HCL': 24, 'BENAZEPRIL HCL': 29,...
#
#                                   provider_variables         npi
# 0  {'settlement_type': 'non-urban', 'generic_rx_c...  1295763035
# 1  {'settlement_type': 'non-urban', 'generic_rx_c...  1992715205
# 2  {'settlement_type': 'non-urban', 'generic_rx_c...  1578587630
# 3  {'settlement_type': 'non-urban', 'generic_rx_c...  1932278405
# 4  {'settlement_type': 'non-urban', 'generic_rx_c...  1437366804

# %%
# Create Test Data
test = data.head().copy()
test
# Out:
#                              cms_prescription_counts  \
# 0  {'DOXAZOSIN MESYLATE': 26, 'MIDODRINE HCL': 12...
# 1  {'CEPHALEXIN': 23, 'AMOXICILLIN': 52, 'HYDROCO...
# 2  {'CEPHALEXIN': 28, 'AMOXICILLIN': 73, 'CLINDAM...
# 3                                {'AMOXICILLIN': 63}
# 4  {'PIOGLITAZONE HCL': 24, 'BENAZEPRIL HCL': 29,...
#
#                                   provider_variables         npi
# 0  {'settlement_type': 'non-urban', 'generic_rx_c...  1295763035
# 1  {'settlement_type': 'non-urban', 'generic_rx_c...  1992715205
# 2  {'settlement_type': 'non-urban', 'generic_rx_c...  1578587630
# 3  {'settlement_type': 'non-urban', 'generic_rx_c...  1932278405
# 4  {'settlement_type': 'non-urban', 'generic_rx_c...  1437366804

# %% [markdown]
# ### Part 2
#
# #### 1-1. Extract Provider Data - List Comprehension

# %%
# %time providerData = pd.DataFrame([x for x in test.provider_variables])

providerData
# Out:
# CPU times: user 1.89 ms, sys: 124 µs, total: 2.02 ms
# Wall time: 2.35 ms
#   settlement_type  generic_rx_count         specialty  years_practicing  \
# 0       non-urban              2287        Nephrology                 7
# 1       non-urban               103  General Practice                 7
# 2       non-urban               112  General Practice                 7
# 3       non-urban                63  General Practice                 7
# 4       non-urban              1035        Nephrology                 6
#
#   gender   region  brand_name_rx_count
# 0      M    South                  384
# 1      M    South                    0
# 2      M  Midwest                    0
# 3      M    South                    0
# 4      M     West                  316

# %% [markdown]
# #### 1-2. Add NPI column as index

# %%
providerData['npi'] = test['npi']
providerData.set_index('npi', inplace=True)
providerData
# Out:
#            settlement_type  generic_rx_count         specialty  \
# npi
# 1295763035       non-urban              2287        Nephrology
# 1992715205       non-urban               103  General Practice
# 1578587630       non-urban               112  General Practice
# 1932278405       non-urban                63  General Practice
# 1437366804       non-urban              1035        Nephrology
#
#             years_practicing gender   region  brand_name_rx_count
# npi
# 1295763035                 7      M    South                  384
# 1992715205                 7      M    South                    0
# 1578587630                 7      M  Midwest                    0
# 1932278405                 7      M    South                    0
# 1437366804                 6      M     West                  316

# %% [markdown]
# ---

# %% [markdown]
# #### 2-1. Extract Provider Data - JSON Normalize

# %%
# %time providerData2 = json_normalize(data=test.provider_variables)
type(providerData2)
# Out:
# CPU times: user 1.2 ms, sys: 140 µs, total: 1.34 ms
# Wall time: 1.24 ms
# pandas.core.frame.DataFrame

# %%
providerData2
# Out:
#   settlement_type  generic_rx_count         specialty  years_practicing  \
# 0       non-urban              2287        Nephrology                 7
# 1       non-urban               103  General Practice                 7
# 2       non-urban               112  General Practice                 7
# 3       non-urban                63  General Practice                 7
# 4       non-urban              1035        Nephrology                 6
#
#   gender   region  brand_name_rx_count
# 0      M    South                  384
# 1      M    South                    0
# 2      M  Midwest                    0
# 3      M    South                    0
# 4      M     West                  316

# %% [markdown]
# #### 2-2. Add NPI column as index

# %%
providerData2['npi'] = test['npi']
providerData2.set_index('npi', inplace=True)

providerData2
# Out:
#            settlement_type  generic_rx_count         specialty  \
# npi
# 1295763035       non-urban              2287        Nephrology
# 1992715205       non-urban               103  General Practice
# 1578587630       non-urban               112  General Practice
# 1932278405       non-urban                63  General Practice
# 1437366804       non-urban              1035        Nephrology
#
#             years_practicing gender   region  brand_name_rx_count
# npi
# 1295763035                 7      M    South                  384
# 1992715205                 7      M    South                    0
# 1578587630                 7      M  Midwest                    0
# 1932278405                 7      M    South                    0
# 1437366804                 6      M     West                  316

# %% [markdown]
# ### Part 3
#
# #### 1.1. Extract Perscription Data - List Comprehension

# %%
# %time perscriptionData = pd.DataFrame([x for x in test.cms_prescription_counts])

print(f"\nDataFrame shape: {perscriptionData.shape}")
# Out:
# CPU times: user 9.87 ms, sys: 2.38 ms, total: 12.3 ms
# Wall time: 12.4 ms
#
# DataFrame shape: (5, 97)

# %% [markdown]
# #### 1-2. Add NPI column as index

# %%
perscriptionData['npi'] = test['npi']
perscriptionData.set_index('npi', inplace=True)

perscriptionData
# Out:
#             DOXAZOSIN MESYLATE  MIDODRINE HCL  MEGESTROL ACETATE  \
# npi
# 1295763035                26.0           12.0               11.0
# 1992715205                 NaN            NaN                NaN
# 1578587630                 NaN            NaN                NaN
# 1932278405                 NaN            NaN                NaN
# 1437366804                 NaN            NaN                NaN
#
#             BENAZEPRIL HCL  METOLAZONE  NOVOLOG  DIAZEPAM  HYDRALAZINE HCL  \
# npi
# 1295763035            11.0        73.0     12.0      24.0             50.0
# 1992715205             NaN         NaN      NaN       NaN              NaN
# 1578587630             NaN         NaN      NaN       NaN              NaN
# 1932278405             NaN         NaN      NaN       NaN              NaN
# 1437366804            29.0         NaN      NaN      26.0             12.0
#
#             SENSIPAR  LABETALOL HCL  ...  ANDROGEL  BUPROPION HCL  \
# npi                                  ...
# 1295763035      94.0           28.0  ...       NaN            NaN
# 1992715205       NaN            NaN  ...       NaN            NaN
# 1578587630       NaN            NaN  ...       NaN            NaN
# 1932278405       NaN            NaN  ...       NaN            NaN
# 1437366804      90.0           13.0  ...      13.0           13.0
#
#             DIPHENOXYLATE-ATROPINE  CRESTOR  LORAZEPAM  DONEPEZIL HCL  \
# npi
# 1295763035                     NaN      NaN        NaN            NaN
# 1992715205                     NaN      NaN        NaN            NaN
# 1578587630                     NaN      NaN        NaN            NaN
# 1932278405                     NaN      NaN        NaN            NaN
# 1437366804                    14.0     18.0       40.0           11.0
#
#             ESTRADIOL  HYDROXYZINE HCL  FLUTICASONE PROPIONATE  \
# npi
# 1295763035        NaN              NaN                     NaN
# 1992715205        NaN              NaN                     NaN
# 1578587630        NaN              NaN                     NaN
# 1932278405        NaN              NaN                     NaN
# 1437366804       37.0             13.0                    11.0
#
#             CALCITONIN-SALMON
# npi
# 1295763035                NaN
# 1992715205                NaN
# 1578587630                NaN
# 1932278405                NaN
# 1437366804               15.0
#
# [5 rows x 97 columns]

# %%
# For reference
test
# Out:
#                              cms_prescription_counts  \
# 0  {'DOXAZOSIN MESYLATE': 26, 'MIDODRINE HCL': 12...
# 1  {'CEPHALEXIN': 23, 'AMOXICILLIN': 52, 'HYDROCO...
# 2  {'CEPHALEXIN': 28, 'AMOXICILLIN': 73, 'CLINDAM...
# 3                                {'AMOXICILLIN': 63}
# 4  {'PIOGLITAZONE HCL': 24, 'BENAZEPRIL HCL': 29,...
#
#                                   provider_variables         npi
# 0  {'settlement_type': 'non-urban', 'generic_rx_c...  1295763035
# 1  {'settlement_type': 'non-urban', 'generic_rx_c...  1992715205
# 2  {'settlement_type': 'non-urban', 'generic_rx_c...  1578587630
# 3  {'settlement_type': 'non-urban', 'generic_rx_c...  1932278405
# 4  {'settlement_type': 'non-urban', 'generic_rx_c...  1437366804
