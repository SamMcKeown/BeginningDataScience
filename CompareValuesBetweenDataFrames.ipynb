# %% [markdown]
# ### Sections
# - 1. Concatenate DataFrames
# - 2. Swap column levels
# - 3. Function
# - 4. Return a styler object
#     -  4.1 Function guide
#
# ### Libraries
# - NumPy
# - python
#
# #### Learning
# - numpy.where
# - pandas.DataFrame.swaplevel
# - pandas.DataFrame.xs
# - pandas.DataFrame.ne
# - pandas.DataFrame.style

# %%
import numpy as np
import pandas as pd

# %%
# Dictionary
dataset_1 = {
            'Name': ['Amy', 'Brian', 'Hugh', 'Karen'],
            'Age': [31, 25, 17, 40], 
            'Nationality': ['UK', 'Ireland', 'Ireland', 'UK']
            }

# Construct DataFrame from a dictionary
df1 = pd.DataFrame(dataset_1)

# Dictionary
dataset_2 = {
            'Name': ['Amy', 'Brian', 'Hugh', 'Karen'], 
            'Age': [51, 25, 37, 40], 
            'Nationality': ['UK', 'Sweden', 'Ireland', '']
            }

# Construct DataFrame from a dictionary
df2 = pd.DataFrame(dataset_2)

display(df1, df2)
# Out:
#     Name  Age Nationality
# 0    Amy   31          UK
# 1  Brian   25     Ireland
# 2   Hugh   17     Ireland
# 3  Karen   40          UK
#     Name  Age Nationality
# 0    Amy   51          UK
# 1  Brian   25      Sweden
# 2   Hugh   37     Ireland
# 3  Karen   40

# %% [markdown]
# ### 1. Concatenate DataFrames
# - Note: index must be the same for both DataFrames

# %%
# Concatenate DataFrames
dataframe = pd.concat(
                     [df1.set_index('Name'), 
                      df2.set_index('Name')], 
                      axis=1, keys=['DataFrame1', 'DataFrame2']
                     ) 

display(dataframe)
# Out:
#       DataFrame1             DataFrame2
#              Age Nationality        Age Nationality
# Name
# Amy           31          UK         51          UK
# Brian         25     Ireland         25      Sweden
# Hugh          17     Ireland         37     Ireland
# Karen         40          UK         40

# %% [markdown]
# ### 2. Swap column levels
#
# - Note: this positions columns with the same name side-by-side

# %%
# Concatenated DataFrame
print('> Step 1.')
display(dataframe)

# Swaplevel
print('> Step 2.')
display(dataframe.swaplevel(axis=1))

# Position columns with the same name side-by-side 
print('> Step 3.')
display(dataframe.swaplevel(axis=1)[df1.columns[1:]])
# Out:
# > Step 1.
#       DataFrame1             DataFrame2
#              Age Nationality        Age Nationality
# Name
# Amy           31          UK         51          UK
# Brian         25     Ireland         25      Sweden
# Hugh          17     Ireland         37     Ireland
# Karen         40          UK         40
# > Step 2.
#              Age Nationality        Age Nationality
#       DataFrame1  DataFrame1 DataFrame2  DataFrame2
# Name
# Amy           31          UK         51          UK
# Brian         25     Ireland         25      Sweden
# Hugh          17     Ireland         37     Ireland
# Karen         40          UK         40
# > Step 3.
#              Age            Nationality
#       DataFrame1 DataFrame2  DataFrame1 DataFrame2
# Name
# Amy           31         51          UK         UK
# Brian         25         25     Ireland     Sweden
# Hugh          17         37     Ireland    Ireland
# Karen         40         40          UK

# %%
# Apply swaplevel to concatenated DataFrame
dataframe = dataframe.swaplevel(axis=1)[df1.columns[1:]]

# %% [markdown]
# ### 3. Function

# %%
def highlightDifference(dataframe, color='Pink'):
    '''
    Function that builds & returns a styled HTML representation of the DataFrame 
   
    Parameters
    ----------
    dataframe : str
        pandas DataFrame
    color : str
        styler background-color 
    ''' 
    attr = 'background-color: {}'.format(color)
    
    other = dataframe.xs(key='DataFrame1', axis=1, level=1)
    
    return pd.DataFrame(
                        np.where(dataframe.ne(other, level=0), attr, ''), 
                        index=dataframe.index, 
                        columns=dataframe.columns
                       )

# %% [markdown]
# ### 4. Return a styler object
#
# #### Note: to view rendered notebook: https://nbviewer.jupyter.org/

# %%
display(dataframe.style.apply(highlightDifference, axis=None))
# Out:
# <style type="text/css">
# #T_52d08_row0_col1, #T_52d08_row1_col3, #T_52d08_row2_col1, #T_52d08_row3_col3 {
#   background-color: Pink;
# }
# </style>
# <table id="T_52d08_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Age</th>
#       <th class="col_heading level0 col2" colspan="2">Nationality</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >DataFrame1</th>
#       <th class="col_heading level1 col1" >DataFrame2</th>
#       <th class="col_heading level1 col2" >DataFrame1</th>
#       <th class="col_heading level1 col3" >DataFrame2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52d08_level0_row0" class="row_heading level0 row0" >Amy</th>
#       <td id="T_52d08_row0_col0" class="data row0 col0" >31</td>
#       <td id="T_52d08_row0_col1" class="data row0 col1" >51</td>
#       <td id="T_52d08_row0_col2" class="data row0 col2" >UK</td>
#       <td id="T_52d08_row0_col3" class="data row0 col3" >UK</td>
#     </tr>
#     <tr>
#       <th id="T_52d08_level0_row1" class="row_heading level0 row1" >Brian</th>
#       <td id="T_52d08_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_52d08_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_52d08_row1_col2" class="data row1 col2" >Ireland</td>
#       <td id="T_52d08_row1_col3" class="data row1 col3" >Sweden</td>
#     </tr>
#     <tr>
#       <th id="T_52d08_level0_row2" class="row_heading level0 row2" >Hugh</th>
#       <td id="T_52d08_row2_col0" class="data row2 col0" >17</td>
#       <td id="T_52d08_row2_col1" class="data row2 col1" >37</td>
#       <td id="T_52d08_row2_col2" class="data row2 col2" >Ireland</td>
#       <td id="T_52d08_row2_col3" class="data row2 col3" >Ireland</td>
#     </tr>
#     <tr>
#       <th id="T_52d08_level0_row3" class="row_heading level0 row3" >Karen</th>
#       <td id="T_52d08_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_52d08_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_52d08_row3_col2" class="data row3 col2" >UK</td>
#       <td id="T_52d08_row3_col3" class="data row3 col3" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.1 Function guide

# %%
# Define color for styler
color = 'Pink'
attr = 'background-color: {}'.format(color)
print(attr)
# Out:
# background-color: Pink

# %%
# Takes a key argument to select data at specific level of multi-index
other = dataframe.xs(key='DataFrame1', axis=1, level=1)
display(other)
# Out:
#        Age Nationality
# Name
# Amy     31          UK
# Brian   25     Ireland
# Hugh    17     Ireland
# Karen   40          UK

# %%
# A flexible way of performing inequality comparison (True: different value)
display(dataframe.ne(other=other, level=0))
# Out:
#              Age            Nationality
#       DataFrame1 DataFrame2  DataFrame1 DataFrame2
# Name
# Amy        False       True       False      False
# Brian      False      False       False       True
# Hugh       False       True       False      False
# Karen      False      False       False       True

# %%
# Apply 'attr' if True (i.e. defined color), otherwise apply ''
display(np.where(dataframe.ne(other=other, level=0), attr, ''))
# Out:
# array([['', 'background-color: Pink', '', ''],
#        ['', '', '', 'background-color: Pink'],
#        ['', 'background-color: Pink', '', ''],
#        ['', '', '', 'background-color: Pink']], dtype='<U22')

# %%
# Converts array into DataFrame
display(pd.DataFrame(
                     np.where(dataframe.ne(other, level=0), attr, ''), 
                     index=dataframe.index, 
                     columns=dataframe.columns
                       ))
# Out:
#              Age                         Nationality
#       DataFrame1              DataFrame2  DataFrame1              DataFrame2
# Name
# Amy               background-color: Pink
# Brian                                                 background-color: Pink
# Hugh              background-color: Pink
# Karen                                                 background-color: Pink
